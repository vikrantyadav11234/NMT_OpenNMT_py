# %% [markdown]
# <a href="https://colab.research.google.com/github/vikrantyadav11234/NMT_OpenNMT_py/blob/main/Machine_translation_with_hugging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install sentencepiece

# %%
from transformers import MarianMTModel, MarianTokenizer

# Define the source and target languages
source_lang = "en"
target_lang = "fr"

# Load the tokenizer and model
model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
def translate(text, tokenizer, model):
    # Tokenize the input text
    tokenized_text = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt")
    # Generate translation using the model
    translation_tokens = model.generate(**tokenized_text)
    # Decode the generated tokens
    translation = tokenizer.batch_decode(translation_tokens, skip_special_tokens=True)[0]
    return translation

# Example usage
text_to_translate = "Hello, how are you?"
translated_text = translate(text_to_translate, tokenizer, model)
print(f"Translated text: {translated_text}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:4072: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, text_target=tgt_texts, ...)
#
# If you either need to use different keyword arguments for the source and target texts, you should do two calls like
# this:
#
# model_inputs = tokenizer(src_texts, ...)
# labels = tokenizer(text_target=tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# Translated text: Bonjour, comment allez-vous?

# %%
def translate(text, tokenizer, model):
    # Tokenize the input text
    tokenized_text = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt")
    # Generate translation using the model
    translation_tokens = model.generate(**tokenized_text)
    # Decode the generated tokens
    translation = tokenizer.batch_decode(translation_tokens, skip_special_tokens=True)[0]
    return translation


text_to_translate = "Hello, how are you?"
translated_text = translate(text_to_translate, tokenizer, model)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: Bonjour, comment allez-vous?

# %%
def load_translation_model(source_lang, target_lang):
    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    return tokenizer, model

def translate_text(text, source_lang, target_lang):
    tokenizer, model = load_translation_model(source_lang, target_lang)
    return translate(text, tokenizer, model)


text_to_translate = "Hello, how are you?"
target_language = "hi"

translated_text = translate_text(text_to_translate, "en", target_language)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: हैलो, तुम कैसे हो?

# %%
text_to_translate = "Dinesh Saklani says changes were made by experts as books do not want to create ‘violent, depressed’ citizens."
target_language = "hi"

translated_text = translate_text(text_to_translate, "en", target_language)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: इस तरह के बदलावों को विशेषज्ञों ने बदल दिया है और वे ‘ हताश और हताश नागरिक ’ नहीं बनना चाहते ।

# %%
text_to_translate = "Dinesh Saklani says changes were made by experts as books do not want to create ‘violent, depressed’ citizens."
target_language = "hi"

translated_text = translate_text(text_to_translate, "en", target_language)
print(f"Translated text: {translated_text}")

# %%
text_to_translate = "Revising textbooks is an annual exercise."
target_language = "hi"

translated_text = translate_text(text_to_translate, "en", target_language)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: पाठ्य - पुस्तक को पुनरुत्थित करना वार्षिक व्यायाम है ।

# %%
from transformers import MT5Tokenizer, MT5ForConditionalGeneration

# Load the tokenizer and model
model_name = "google/mt5-small"
tokenizer = MT5Tokenizer.from_pretrained(model_name)
model = MT5ForConditionalGeneration.from_pretrained(model_name)

# %%
def translate(text, source_lang, target_lang):
    input_text = f"translate {source_lang} to {target_lang}: {text}"
    inputs = tokenizer.encode(input_text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=512, num_beams=4, early_stopping=True)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text


text= "Hello, how are you?"
source_language = "en"
target_language = "fr"

translated_text = translate(text, source_language, target_language)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: <extra_id_0>

# %%
def translate_text(text, source_lang, target_lang):
    input_text = f"translate {source_lang} to {target_lang}: {text}"
    inputs = tokenizer.encode(input_text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=512, num_beams=4, early_stopping=True)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text


text_to_translate = "Hello, how are you?"
translated_text = translate_text(text_to_translate, "en", "hi")
print(f"Translated text: {translated_text}")
# Out:
# Translated text: <extra_id_0>
